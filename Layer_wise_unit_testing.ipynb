# %% [markdown]
# <a href="https://colab.research.google.com/github/john-jehiel/cards-image-classification/blob/main/Layer_wise_unit_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install thop
# Out:
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from thop) (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->thop) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->thop) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->thop) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->thop) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->thop) (3.0.2)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Installing collected packages: thop
# Successfully installed thop-0.1.1.post2209072238

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from thop import profile

# %% [markdown]
# ### Utility Functions

# %%
# get list of all layers in a model
def get_layers(model):
    test_layers = []
    for name, layer in model.named_modules():
        if len(list(layer.children())) == 0:  # Only include layers without further submodules
            test_layers.append((layer, f"{name} ({layer.__class__.__name__})"))
    return test_layers

# %%
# utility function for easily copying list of test layers
def pretty_print(lst):
    print('[')
    for layer in lst:
        print("   ", layer, ",")
    print(']')

# %% [markdown]
# ### CNN Architecture

# %%
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1   = nn.Conv2d(3, 64, 3)
        self.pool1   = nn.MaxPool2d(2,2)
        self.conv2   = nn.Conv2d(64, 64, 3)
        self.pool2   = nn.MaxPool2d(2,2)
        self.conv3   = nn.Conv2d(64, 64, 3)
        self.pool3   = nn.MaxPool2d(2,2)

        self.f1      = nn.Linear(64 * 26 * 26, 128)
        self.f2      = nn.Linear(128, 128)
        self.f3      = nn.Linear(128, 53)


    def forward(self, x):

        x = self.pool1(F.relu(self.conv1(x)))
        x = self.pool2(F.relu(self.conv2(x)))
        x = self.pool3(F.relu(self.conv3(x)))

        x = x.view(-1, 26 * 26 * 64)

        x = F.relu(self.f1(x))
        x = F.relu(self.f2(x))
        x = self.f3(x)
        return x

# %%
model = CNN()

# %%
test_layers = get_layers(model)

# %%
pretty_print(test_layers)
# Out:
# [
#     (Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1)), 'conv1 (Conv2d)') ,
#     (MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False), 'pool1 (MaxPool2d)') ,
#     (Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1)), 'conv2 (Conv2d)') ,
#     (MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False), 'pool2 (MaxPool2d)') ,
#     (Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1)), 'conv3 (Conv2d)') ,
#     (MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False), 'pool3 (MaxPool2d)') ,
#     (Linear(in_features=43264, out_features=128, bias=True), 'f1 (Linear)') ,
#     (Linear(in_features=128, out_features=128, bias=True), 'f2 (Linear)') ,
#     (Linear(in_features=128, out_features=53, bias=True), 'f3 (Linear)') ,
# ]

# %% [markdown]
# ### EfficientNet Architecture Without Batchnorm

# %%
import torchvision.models as models
from torchvision.models.efficientnet import EfficientNet_B0_Weights

class EfficientNet1(nn.Module):
    def __init__(self):
        super(EfficientNet1, self).__init__()
        # Load EfficientNetB0 backbone
        self.base_model = models.efficientnet_b0(pretrained=True)
        self.base_model.features.requires_grad_(False)  # Freeze base model layers

        self.pooling = nn.AdaptiveAvgPool2d(1)

        self.fc1 = nn.Linear(1280, 128)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(128, 53)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.base_model.features(x)
        x = self.pooling(x).squeeze(-1).squeeze(-1)  # Global average pooling
        x = self.fc1(x)

        x = self.relu(x)
        x = self.fc2(x)
        return self.softmax(x)

# %%
model = EfficientNet1()
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 93.3MB/s]

# %%
test_layers = get_layers(model)

# %%
pretty_print(test_layers)
# Out:
# [
#     (Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False), 'base_model.features.0.0 (Conv2d)') ,
#     (BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.0.2 (SiLU)') ,
#     (Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False), 'base_model.features.1.0.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.1.0.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.1.0.block.0.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.1.0.block.1.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.1.0.block.1.fc1 (Conv2d)') ,
#     (Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.1.0.block.1.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.1.0.block.1.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.1.0.block.1.scale_activation (Sigmoid)') ,
#     (Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.1.0.block.2.0 (Conv2d)') ,
#     (BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.1.0.block.2.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.0, mode=row), 'base_model.features.1.0.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.2.0.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.2.0.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.2.0.block.0.2 (SiLU)') ,
#     (Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False), 'base_model.features.2.0.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.2.0.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.2.0.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.2.0.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.2.0.block.2.fc1 (Conv2d)') ,
#     (Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.2.0.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.2.0.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.2.0.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.2.0.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.2.0.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.0125, mode=row), 'base_model.features.2.0.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.2.1.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.2.1.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.2.1.block.0.2 (SiLU)') ,
#     (Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False), 'base_model.features.2.1.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.2.1.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.2.1.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.2.1.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.2.1.block.2.fc1 (Conv2d)') ,
#     (Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.2.1.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.2.1.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.2.1.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.2.1.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.2.1.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.025, mode=row), 'base_model.features.2.1.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.3.0.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.3.0.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.3.0.block.0.2 (SiLU)') ,
#     (Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False), 'base_model.features.3.0.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.3.0.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.3.0.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.3.0.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.3.0.block.2.fc1 (Conv2d)') ,
#     (Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.3.0.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.3.0.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.3.0.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.3.0.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.3.0.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.037500000000000006, mode=row), 'base_model.features.3.0.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.3.1.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.3.1.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.3.1.block.0.2 (SiLU)') ,
#     (Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False), 'base_model.features.3.1.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.3.1.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.3.1.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.3.1.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.3.1.block.2.fc1 (Conv2d)') ,
#     (Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.3.1.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.3.1.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.3.1.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.3.1.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.3.1.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.05, mode=row), 'base_model.features.3.1.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.4.0.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.4.0.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.4.0.block.0.2 (SiLU)') ,
#     (Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False), 'base_model.features.4.0.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.4.0.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.4.0.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.4.0.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.4.0.block.2.fc1 (Conv2d)') ,
#     (Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.4.0.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.4.0.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.4.0.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.4.0.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.4.0.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.0625, mode=row), 'base_model.features.4.0.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.4.1.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.4.1.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.4.1.block.0.2 (SiLU)') ,
#     (Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False), 'base_model.features.4.1.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.4.1.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.4.1.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.4.1.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.4.1.block.2.fc1 (Conv2d)') ,
#     (Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.4.1.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.4.1.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.4.1.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.4.1.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.4.1.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.07500000000000001, mode=row), 'base_model.features.4.1.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.4.2.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.4.2.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.4.2.block.0.2 (SiLU)') ,
#     (Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False), 'base_model.features.4.2.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.4.2.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.4.2.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.4.2.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.4.2.block.2.fc1 (Conv2d)') ,
#     (Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.4.2.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.4.2.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.4.2.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.4.2.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.4.2.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.08750000000000001, mode=row), 'base_model.features.4.2.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.5.0.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.5.0.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.5.0.block.0.2 (SiLU)') ,
#     (Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False), 'base_model.features.5.0.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.5.0.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.5.0.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.5.0.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.5.0.block.2.fc1 (Conv2d)') ,
#     (Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.5.0.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.5.0.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.5.0.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.5.0.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.5.0.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.1, mode=row), 'base_model.features.5.0.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.5.1.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.5.1.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.5.1.block.0.2 (SiLU)') ,
#     (Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False), 'base_model.features.5.1.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.5.1.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.5.1.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.5.1.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.5.1.block.2.fc1 (Conv2d)') ,
#     (Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.5.1.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.5.1.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.5.1.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.5.1.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.5.1.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.1125, mode=row), 'base_model.features.5.1.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.5.2.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.5.2.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.5.2.block.0.2 (SiLU)') ,
#     (Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False), 'base_model.features.5.2.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.5.2.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.5.2.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.5.2.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.5.2.block.2.fc1 (Conv2d)') ,
#     (Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.5.2.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.5.2.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.5.2.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.5.2.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.5.2.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.125, mode=row), 'base_model.features.5.2.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.6.0.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.0.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.0.block.0.2 (SiLU)') ,
#     (Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False), 'base_model.features.6.0.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.0.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.0.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.6.0.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.6.0.block.2.fc1 (Conv2d)') ,
#     (Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.6.0.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.0.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.6.0.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.6.0.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.0.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.1375, mode=row), 'base_model.features.6.0.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.6.1.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.1.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.1.block.0.2 (SiLU)') ,
#     (Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False), 'base_model.features.6.1.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.1.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.1.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.6.1.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.6.1.block.2.fc1 (Conv2d)') ,
#     (Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.6.1.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.1.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.6.1.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.6.1.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.1.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.15000000000000002, mode=row), 'base_model.features.6.1.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.6.2.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.2.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.2.block.0.2 (SiLU)') ,
#     (Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False), 'base_model.features.6.2.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.2.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.2.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.6.2.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.6.2.block.2.fc1 (Conv2d)') ,
#     (Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.6.2.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.2.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.6.2.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.6.2.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.2.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.1625, mode=row), 'base_model.features.6.2.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.6.3.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.3.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.3.block.0.2 (SiLU)') ,
#     (Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False), 'base_model.features.6.3.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.3.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.3.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.6.3.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.6.3.block.2.fc1 (Conv2d)') ,
#     (Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.6.3.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.3.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.6.3.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.6.3.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.3.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.17500000000000002, mode=row), 'base_model.features.6.3.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.7.0.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.7.0.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.7.0.block.0.2 (SiLU)') ,
#     (Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False), 'base_model.features.7.0.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.7.0.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.7.0.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.7.0.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.7.0.block.2.fc1 (Conv2d)') ,
#     (Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.7.0.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.7.0.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.7.0.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.7.0.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.7.0.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.1875, mode=row), 'base_model.features.7.0.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.8.0 (Conv2d)') ,
#     (BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.8.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.8.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.avgpool (AdaptiveAvgPool2d)') ,
#     (Dropout(p=0.2, inplace=True), 'base_model.classifier.0 (Dropout)') ,
#     (Linear(in_features=1280, out_features=1000, bias=True), 'base_model.classifier.1 (Linear)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'pooling (AdaptiveAvgPool2d)') ,
#     (Linear(in_features=1280, out_features=128, bias=True), 'fc1 (Linear)') ,
#     (ReLU(), 'relu (ReLU)') ,
#     (Linear(in_features=128, out_features=53, bias=True), 'fc2 (Linear)') ,
#     (Softmax(dim=1), 'softmax (Softmax)') ,
# ]

# %% [markdown]
# ### EfficientNet Architecture With Batchnorm

# %%
import torchvision.models as models
from torchvision.models.efficientnet import EfficientNet_B0_Weights

class EfficientNet2(nn.Module):
    def __init__(self):
        super(EfficientNet2, self).__init__()
        # Load EfficientNetB0 backbone
        self.base_model = models.efficientnet_b0(pretrained=True)
        self.base_model.features.requires_grad_(False)  # Freeze base model layers

        self.pooling = nn.AdaptiveAvgPool2d(1)
        self.batch_norm = nn.BatchNorm1d(128)
        self.fc1 = nn.Linear(1280, 128)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(128, 53)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.base_model.features(x)
        x = self.pooling(x).squeeze(-1).squeeze(-1)  # Global average pooling
        x = self.fc1(x)
        x = self.batch_norm(x)
        x = self.relu(x)
        x = self.fc2(x)
        return self.softmax(x)

# %%
model = EfficientNet2()

# %%
test_layers = get_layers(model)

# %%
pretty_print(test_layers)
# Out:
# [
#     (Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False), 'base_model.features.0.0 (Conv2d)') ,
#     (BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.0.2 (SiLU)') ,
#     (Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False), 'base_model.features.1.0.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.1.0.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.1.0.block.0.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.1.0.block.1.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.1.0.block.1.fc1 (Conv2d)') ,
#     (Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.1.0.block.1.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.1.0.block.1.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.1.0.block.1.scale_activation (Sigmoid)') ,
#     (Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.1.0.block.2.0 (Conv2d)') ,
#     (BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.1.0.block.2.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.0, mode=row), 'base_model.features.1.0.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.2.0.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.2.0.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.2.0.block.0.2 (SiLU)') ,
#     (Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False), 'base_model.features.2.0.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.2.0.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.2.0.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.2.0.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.2.0.block.2.fc1 (Conv2d)') ,
#     (Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.2.0.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.2.0.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.2.0.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.2.0.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.2.0.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.0125, mode=row), 'base_model.features.2.0.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.2.1.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.2.1.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.2.1.block.0.2 (SiLU)') ,
#     (Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False), 'base_model.features.2.1.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.2.1.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.2.1.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.2.1.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.2.1.block.2.fc1 (Conv2d)') ,
#     (Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.2.1.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.2.1.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.2.1.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.2.1.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.2.1.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.025, mode=row), 'base_model.features.2.1.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.3.0.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.3.0.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.3.0.block.0.2 (SiLU)') ,
#     (Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False), 'base_model.features.3.0.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.3.0.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.3.0.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.3.0.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.3.0.block.2.fc1 (Conv2d)') ,
#     (Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.3.0.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.3.0.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.3.0.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.3.0.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.3.0.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.037500000000000006, mode=row), 'base_model.features.3.0.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.3.1.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.3.1.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.3.1.block.0.2 (SiLU)') ,
#     (Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False), 'base_model.features.3.1.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.3.1.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.3.1.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.3.1.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.3.1.block.2.fc1 (Conv2d)') ,
#     (Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.3.1.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.3.1.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.3.1.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.3.1.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.3.1.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.05, mode=row), 'base_model.features.3.1.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.4.0.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.4.0.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.4.0.block.0.2 (SiLU)') ,
#     (Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False), 'base_model.features.4.0.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.4.0.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.4.0.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.4.0.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.4.0.block.2.fc1 (Conv2d)') ,
#     (Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.4.0.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.4.0.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.4.0.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.4.0.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.4.0.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.0625, mode=row), 'base_model.features.4.0.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.4.1.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.4.1.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.4.1.block.0.2 (SiLU)') ,
#     (Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False), 'base_model.features.4.1.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.4.1.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.4.1.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.4.1.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.4.1.block.2.fc1 (Conv2d)') ,
#     (Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.4.1.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.4.1.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.4.1.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.4.1.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.4.1.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.07500000000000001, mode=row), 'base_model.features.4.1.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.4.2.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.4.2.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.4.2.block.0.2 (SiLU)') ,
#     (Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False), 'base_model.features.4.2.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.4.2.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.4.2.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.4.2.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.4.2.block.2.fc1 (Conv2d)') ,
#     (Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.4.2.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.4.2.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.4.2.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.4.2.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.4.2.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.08750000000000001, mode=row), 'base_model.features.4.2.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.5.0.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.5.0.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.5.0.block.0.2 (SiLU)') ,
#     (Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False), 'base_model.features.5.0.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.5.0.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.5.0.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.5.0.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.5.0.block.2.fc1 (Conv2d)') ,
#     (Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.5.0.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.5.0.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.5.0.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.5.0.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.5.0.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.1, mode=row), 'base_model.features.5.0.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.5.1.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.5.1.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.5.1.block.0.2 (SiLU)') ,
#     (Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False), 'base_model.features.5.1.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.5.1.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.5.1.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.5.1.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.5.1.block.2.fc1 (Conv2d)') ,
#     (Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.5.1.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.5.1.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.5.1.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.5.1.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.5.1.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.1125, mode=row), 'base_model.features.5.1.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.5.2.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.5.2.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.5.2.block.0.2 (SiLU)') ,
#     (Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False), 'base_model.features.5.2.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.5.2.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.5.2.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.5.2.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.5.2.block.2.fc1 (Conv2d)') ,
#     (Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.5.2.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.5.2.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.5.2.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.5.2.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.5.2.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.125, mode=row), 'base_model.features.5.2.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.6.0.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.0.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.0.block.0.2 (SiLU)') ,
#     (Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False), 'base_model.features.6.0.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.0.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.0.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.6.0.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.6.0.block.2.fc1 (Conv2d)') ,
#     (Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.6.0.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.0.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.6.0.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.6.0.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.0.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.1375, mode=row), 'base_model.features.6.0.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.6.1.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.1.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.1.block.0.2 (SiLU)') ,
#     (Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False), 'base_model.features.6.1.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.1.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.1.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.6.1.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.6.1.block.2.fc1 (Conv2d)') ,
#     (Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.6.1.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.1.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.6.1.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.6.1.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.1.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.15000000000000002, mode=row), 'base_model.features.6.1.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.6.2.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.2.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.2.block.0.2 (SiLU)') ,
#     (Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False), 'base_model.features.6.2.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.2.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.2.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.6.2.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.6.2.block.2.fc1 (Conv2d)') ,
#     (Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.6.2.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.2.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.6.2.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.6.2.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.2.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.1625, mode=row), 'base_model.features.6.2.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.6.3.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.3.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.3.block.0.2 (SiLU)') ,
#     (Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False), 'base_model.features.6.3.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.3.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.3.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.6.3.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.6.3.block.2.fc1 (Conv2d)') ,
#     (Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.6.3.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.6.3.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.6.3.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.6.3.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.6.3.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.17500000000000002, mode=row), 'base_model.features.6.3.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.7.0.block.0.0 (Conv2d)') ,
#     (BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.7.0.block.0.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.7.0.block.0.2 (SiLU)') ,
#     (Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False), 'base_model.features.7.0.block.1.0 (Conv2d)') ,
#     (BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.7.0.block.1.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.7.0.block.1.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.features.7.0.block.2.avgpool (AdaptiveAvgPool2d)') ,
#     (Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.7.0.block.2.fc1 (Conv2d)') ,
#     (Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1)), 'base_model.features.7.0.block.2.fc2 (Conv2d)') ,
#     (SiLU(inplace=True), 'base_model.features.7.0.block.2.activation (SiLU)') ,
#     (Sigmoid(), 'base_model.features.7.0.block.2.scale_activation (Sigmoid)') ,
#     (Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.7.0.block.3.0 (Conv2d)') ,
#     (BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.7.0.block.3.1 (BatchNorm2d)') ,
#     (StochasticDepth(p=0.1875, mode=row), 'base_model.features.7.0.stochastic_depth (StochasticDepth)') ,
#     (Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False), 'base_model.features.8.0 (Conv2d)') ,
#     (BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'base_model.features.8.1 (BatchNorm2d)') ,
#     (SiLU(inplace=True), 'base_model.features.8.2 (SiLU)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'base_model.avgpool (AdaptiveAvgPool2d)') ,
#     (Dropout(p=0.2, inplace=True), 'base_model.classifier.0 (Dropout)') ,
#     (Linear(in_features=1280, out_features=1000, bias=True), 'base_model.classifier.1 (Linear)') ,
#     (AdaptiveAvgPool2d(output_size=1), 'pooling (AdaptiveAvgPool2d)') ,
#     (BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'batch_norm (BatchNorm1d)') ,
#     (Linear(in_features=1280, out_features=128, bias=True), 'fc1 (Linear)') ,
#     (ReLU(), 'relu (ReLU)') ,
#     (Linear(in_features=128, out_features=53, bias=True), 'fc2 (Linear)') ,
#     (Softmax(dim=1), 'softmax (Softmax)') ,
# ]

# %% [markdown]
# ### Testing Phase

# %% [markdown]
# **Unit Tests for CNN**

# %%
# !pytest -v testing.py --model=cnn
# Out:
# ======================================= test session starts ========================================
# platform linux -- Python 3.11.11, pytest-8.3.4, pluggy-1.5.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content
# plugins: typeguard-4.4.1, anyio-3.7.1
# collected 9 items
#
# testing.py::test_mac_computation[layer0-conv1 (Conv2d)] PASSED                               [ 11%]
# testing.py::test_mac_computation[layer1-pool1 (MaxPool2d)] PASSED                            [ 22%]
# testing.py::test_mac_computation[layer2-conv2 (Conv2d)] PASSED                               [ 33%]
# testing.py::test_mac_computation[layer3-pool2 (MaxPool2d)] PASSED                            [ 44%]
# testing.py::test_mac_computation[layer4-conv3 (Conv2d)] PASSED                               [ 55%]
# testing.py::test_mac_computation[layer5-pool3 (MaxPool2d)] PASSED                            [ 66%]
# testing.py::test_mac_computation[layer6-f1 (Linear)] PASSED                                  [ 77%]
# testing.py::test_mac_computation[layer7-f2 (Linear)] PASSED                                  [ 88%]
# testing.py::test_mac_computation[layer8-f3 (Linear)] PASSED                                  [100%]
#
# ======================================== 9 passed in 0.56s =========================================

# %% [markdown]
# **Unit Tests for EfficientNet (without batchnorm)**

# %%
# !pytest -v testing.py --model=efficientnet1
# Out:
# ======================================= test session starts ========================================
# platform linux -- Python 3.11.11, pytest-8.3.4, pluggy-1.5.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content
# plugins: typeguard-4.4.1, anyio-3.7.1
# collected 235 items
#
# testing.py::test_mac_computation[layer0-base_model.features.0.0 (Conv2d)] PASSED             [  0%]
# testing.py::test_mac_computation[layer1-base_model.features.0.1 (BatchNorm2d)] PASSED        [  0%]
# testing.py::test_mac_computation[layer2-base_model.features.0.2 (SiLU)] PASSED               [  1%]
# testing.py::test_mac_computation[layer3-base_model.features.1.0.block.0.0 (Conv2d)] PASSED   [  1%]
# testing.py::test_mac_computation[layer4-base_model.features.1.0.block.0.1 (BatchNorm2d)] PASSED [  2%]
# testing.py::test_mac_computation[layer5-base_model.features.1.0.block.0.2 (SiLU)] PASSED     [  2%]
# testing.py::test_mac_computation[layer6-base_model.features.1.0.block.1.avgpool (AdaptiveAvgPool2d)] PASSED [  2%]
# testing.py::test_mac_computation[layer7-base_model.features.1.0.block.1.fc1 (Conv2d)] PASSED [  3%]
# testing.py::test_mac_computation[layer8-base_model.features.1.0.block.1.fc2 (Conv2d)] PASSED [  3%]
# testing.py::test_mac_computation[layer9-base_model.features.1.0.block.1.activation (SiLU)] PASSED [  4%]
# testing.py::test_mac_computation[layer10-base_model.features.1.0.block.1.scale_activation (Sigmoid)] PASSED [  4%]
# testing.py::test_mac_computation[layer11-base_model.features.1.0.block.2.0 (Conv2d)] PASSED  [  5%]
# testing.py::test_mac_computation[layer12-base_model.features.1.0.block.2.1 (BatchNorm2d)] PASSED [  5%]
# testing.py::test_mac_computation[layer13-base_model.features.1.0.stochastic_depth (StochasticDepth)] PASSED [  5%]
# testing.py::test_mac_computation[layer14-base_model.features.2.0.block.0.0 (Conv2d)] PASSED  [  6%]
# testing.py::test_mac_computation[layer15-base_model.features.2.0.block.0.1 (BatchNorm2d)] PASSED [  6%]
# testing.py::test_mac_computation[layer16-base_model.features.2.0.block.0.2 (SiLU)] PASSED    [  7%]
# testing.py::test_mac_computation[layer17-base_model.features.2.0.block.1.0 (Conv2d)] PASSED  [  7%]
# testing.py::test_mac_computation[layer18-base_model.features.2.0.block.1.1 (BatchNorm2d)] PASSED [  8%]
# testing.py::test_mac_computation[layer19-base_model.features.2.0.block.1.2 (SiLU)] PASSED    [  8%]
# testing.py::test_mac_computation[layer20-base_model.features.2.0.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [  8%]
# testing.py::test_mac_computation[layer21-base_model.features.2.0.block.2.fc1 (Conv2d)] PASSED [  9%]
# testing.py::test_mac_computation[layer22-base_model.features.2.0.block.2.fc2 (Conv2d)] PASSED [  9%]
# testing.py::test_mac_computation[layer23-base_model.features.2.0.block.2.activation (SiLU)] PASSED [ 10%]
# testing.py::test_mac_computation[layer24-base_model.features.2.0.block.2.scale_activation (Sigmoid)] PASSED [ 10%]
# testing.py::test_mac_computation[layer25-base_model.features.2.0.block.3.0 (Conv2d)] PASSED  [ 11%]
# testing.py::test_mac_computation[layer26-base_model.features.2.0.block.3.1 (BatchNorm2d)] PASSED [ 11%]
# testing.py::test_mac_computation[layer27-base_model.features.2.0.stochastic_depth (StochasticDepth)] PASSED [ 11%]
# testing.py::test_mac_computation[layer28-base_model.features.2.1.block.0.0 (Conv2d)] PASSED  [ 12%]
# testing.py::test_mac_computation[layer29-base_model.features.2.1.block.0.1 (BatchNorm2d)] PASSED [ 12%]
# testing.py::test_mac_computation[layer30-base_model.features.2.1.block.0.2 (SiLU)] PASSED    [ 13%]
# testing.py::test_mac_computation[layer31-base_model.features.2.1.block.1.0 (Conv2d)] PASSED  [ 13%]
# testing.py::test_mac_computation[layer32-base_model.features.2.1.block.1.1 (BatchNorm2d)] PASSED [ 14%]
# testing.py::test_mac_computation[layer33-base_model.features.2.1.block.1.2 (SiLU)] PASSED    [ 14%]
# testing.py::test_mac_computation[layer34-base_model.features.2.1.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 14%]
# testing.py::test_mac_computation[layer35-base_model.features.2.1.block.2.fc1 (Conv2d)] PASSED [ 15%]
# testing.py::test_mac_computation[layer36-base_model.features.2.1.block.2.fc2 (Conv2d)] PASSED [ 15%]
# testing.py::test_mac_computation[layer37-base_model.features.2.1.block.2.activation (SiLU)] PASSED [ 16%]
# testing.py::test_mac_computation[layer38-base_model.features.2.1.block.2.scale_activation (Sigmoid)] PASSED [ 16%]
# testing.py::test_mac_computation[layer39-base_model.features.2.1.block.3.0 (Conv2d)] PASSED  [ 17%]
# testing.py::test_mac_computation[layer40-base_model.features.2.1.block.3.1 (BatchNorm2d)] PASSED [ 17%]
# testing.py::test_mac_computation[layer41-base_model.features.2.1.stochastic_depth (StochasticDepth)] PASSED [ 17%]
# testing.py::test_mac_computation[layer42-base_model.features.3.0.block.0.0 (Conv2d)] PASSED  [ 18%]
# testing.py::test_mac_computation[layer43-base_model.features.3.0.block.0.1 (BatchNorm2d)] PASSED [ 18%]
# testing.py::test_mac_computation[layer44-base_model.features.3.0.block.0.2 (SiLU)] PASSED    [ 19%]
# testing.py::test_mac_computation[layer45-base_model.features.3.0.block.1.0 (Conv2d)] PASSED  [ 19%]
# testing.py::test_mac_computation[layer46-base_model.features.3.0.block.1.1 (BatchNorm2d)] PASSED [ 20%]
# testing.py::test_mac_computation[layer47-base_model.features.3.0.block.1.2 (SiLU)] PASSED    [ 20%]
# testing.py::test_mac_computation[layer48-base_model.features.3.0.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 20%]
# testing.py::test_mac_computation[layer49-base_model.features.3.0.block.2.fc1 (Conv2d)] PASSED [ 21%]
# testing.py::test_mac_computation[layer50-base_model.features.3.0.block.2.fc2 (Conv2d)] PASSED [ 21%]
# testing.py::test_mac_computation[layer51-base_model.features.3.0.block.2.activation (SiLU)] PASSED [ 22%]
# testing.py::test_mac_computation[layer52-base_model.features.3.0.block.2.scale_activation (Sigmoid)] PASSED [ 22%]
# testing.py::test_mac_computation[layer53-base_model.features.3.0.block.3.0 (Conv2d)] PASSED  [ 22%]
# testing.py::test_mac_computation[layer54-base_model.features.3.0.block.3.1 (BatchNorm2d)] PASSED [ 23%]
# testing.py::test_mac_computation[layer55-base_model.features.3.0.stochastic_depth (StochasticDepth)] PASSED [ 23%]
# testing.py::test_mac_computation[layer56-base_model.features.3.1.block.0.0 (Conv2d)] PASSED  [ 24%]
# testing.py::test_mac_computation[layer57-base_model.features.3.1.block.0.1 (BatchNorm2d)] PASSED [ 24%]
# testing.py::test_mac_computation[layer58-base_model.features.3.1.block.0.2 (SiLU)] PASSED    [ 25%]
# testing.py::test_mac_computation[layer59-base_model.features.3.1.block.1.0 (Conv2d)] PASSED  [ 25%]
# testing.py::test_mac_computation[layer60-base_model.features.3.1.block.1.1 (BatchNorm2d)] PASSED [ 25%]
# testing.py::test_mac_computation[layer61-base_model.features.3.1.block.1.2 (SiLU)] PASSED    [ 26%]
# testing.py::test_mac_computation[layer62-base_model.features.3.1.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 26%]
# testing.py::test_mac_computation[layer63-base_model.features.3.1.block.2.fc1 (Conv2d)] PASSED [ 27%]
# testing.py::test_mac_computation[layer64-base_model.features.3.1.block.2.fc2 (Conv2d)] PASSED [ 27%]
# testing.py::test_mac_computation[layer65-base_model.features.3.1.block.2.activation (SiLU)] PASSED [ 28%]
# testing.py::test_mac_computation[layer66-base_model.features.3.1.block.2.scale_activation (Sigmoid)] PASSED [ 28%]
# testing.py::test_mac_computation[layer67-base_model.features.3.1.block.3.0 (Conv2d)] PASSED  [ 28%]
# testing.py::test_mac_computation[layer68-base_model.features.3.1.block.3.1 (BatchNorm2d)] PASSED [ 29%]
# testing.py::test_mac_computation[layer69-base_model.features.3.1.stochastic_depth (StochasticDepth)] PASSED [ 29%]
# testing.py::test_mac_computation[layer70-base_model.features.4.0.block.0.0 (Conv2d)] PASSED  [ 30%]
# testing.py::test_mac_computation[layer71-base_model.features.4.0.block.0.1 (BatchNorm2d)] PASSED [ 30%]
# testing.py::test_mac_computation[layer72-base_model.features.4.0.block.0.2 (SiLU)] PASSED    [ 31%]
# testing.py::test_mac_computation[layer73-base_model.features.4.0.block.1.0 (Conv2d)] PASSED  [ 31%]
# testing.py::test_mac_computation[layer74-base_model.features.4.0.block.1.1 (BatchNorm2d)] PASSED [ 31%]
# testing.py::test_mac_computation[layer75-base_model.features.4.0.block.1.2 (SiLU)] PASSED    [ 32%]
# testing.py::test_mac_computation[layer76-base_model.features.4.0.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 32%]
# testing.py::test_mac_computation[layer77-base_model.features.4.0.block.2.fc1 (Conv2d)] PASSED [ 33%]
# testing.py::test_mac_computation[layer78-base_model.features.4.0.block.2.fc2 (Conv2d)] PASSED [ 33%]
# testing.py::test_mac_computation[layer79-base_model.features.4.0.block.2.activation (SiLU)] PASSED [ 34%]
# testing.py::test_mac_computation[layer80-base_model.features.4.0.block.2.scale_activation (Sigmoid)] PASSED [ 34%]
# testing.py::test_mac_computation[layer81-base_model.features.4.0.block.3.0 (Conv2d)] PASSED  [ 34%]
# testing.py::test_mac_computation[layer82-base_model.features.4.0.block.3.1 (BatchNorm2d)] PASSED [ 35%]
# testing.py::test_mac_computation[layer83-base_model.features.4.0.stochastic_depth (StochasticDepth)] PASSED [ 35%]
# testing.py::test_mac_computation[layer84-base_model.features.4.1.block.0.0 (Conv2d)] PASSED  [ 36%]
# testing.py::test_mac_computation[layer85-base_model.features.4.1.block.0.1 (BatchNorm2d)] PASSED [ 36%]
# testing.py::test_mac_computation[layer86-base_model.features.4.1.block.0.2 (SiLU)] PASSED    [ 37%]
# testing.py::test_mac_computation[layer87-base_model.features.4.1.block.1.0 (Conv2d)] PASSED  [ 37%]
# testing.py::test_mac_computation[layer88-base_model.features.4.1.block.1.1 (BatchNorm2d)] PASSED [ 37%]
# testing.py::test_mac_computation[layer89-base_model.features.4.1.block.1.2 (SiLU)] PASSED    [ 38%]
# testing.py::test_mac_computation[layer90-base_model.features.4.1.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 38%]
# testing.py::test_mac_computation[layer91-base_model.features.4.1.block.2.fc1 (Conv2d)] PASSED [ 39%]
# testing.py::test_mac_computation[layer92-base_model.features.4.1.block.2.fc2 (Conv2d)] PASSED [ 39%]
# testing.py::test_mac_computation[layer93-base_model.features.4.1.block.2.activation (SiLU)] PASSED [ 40%]
# testing.py::test_mac_computation[layer94-base_model.features.4.1.block.2.scale_activation (Sigmoid)] PASSED [ 40%]
# testing.py::test_mac_computation[layer95-base_model.features.4.1.block.3.0 (Conv2d)] PASSED  [ 40%]
# testing.py::test_mac_computation[layer96-base_model.features.4.1.block.3.1 (BatchNorm2d)] PASSED [ 41%]
# testing.py::test_mac_computation[layer97-base_model.features.4.1.stochastic_depth (StochasticDepth)] PASSED [ 41%]
# testing.py::test_mac_computation[layer98-base_model.features.4.2.block.0.0 (Conv2d)] PASSED  [ 42%]
# testing.py::test_mac_computation[layer99-base_model.features.4.2.block.0.1 (BatchNorm2d)] PASSED [ 42%]
# testing.py::test_mac_computation[layer100-base_model.features.4.2.block.0.2 (SiLU)] PASSED   [ 42%]
# testing.py::test_mac_computation[layer101-base_model.features.4.2.block.1.0 (Conv2d)] PASSED [ 43%]
# testing.py::test_mac_computation[layer102-base_model.features.4.2.block.1.1 (BatchNorm2d)] PASSED [ 43%]
# testing.py::test_mac_computation[layer103-base_model.features.4.2.block.1.2 (SiLU)] PASSED   [ 44%]
# testing.py::test_mac_computation[layer104-base_model.features.4.2.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 44%]
# testing.py::test_mac_computation[layer105-base_model.features.4.2.block.2.fc1 (Conv2d)] PASSED [ 45%]
# testing.py::test_mac_computation[layer106-base_model.features.4.2.block.2.fc2 (Conv2d)] PASSED [ 45%]
# testing.py::test_mac_computation[layer107-base_model.features.4.2.block.2.activation (SiLU)] PASSED [ 45%]
# testing.py::test_mac_computation[layer108-base_model.features.4.2.block.2.scale_activation (Sigmoid)] PASSED [ 46%]
# testing.py::test_mac_computation[layer109-base_model.features.4.2.block.3.0 (Conv2d)] PASSED [ 46%]
# testing.py::test_mac_computation[layer110-base_model.features.4.2.block.3.1 (BatchNorm2d)] PASSED [ 47%]
# testing.py::test_mac_computation[layer111-base_model.features.4.2.stochastic_depth (StochasticDepth)] PASSED [ 47%]
# testing.py::test_mac_computation[layer112-base_model.features.5.0.block.0.0 (Conv2d)] PASSED [ 48%]
# testing.py::test_mac_computation[layer113-base_model.features.5.0.block.0.1 (BatchNorm2d)] PASSED [ 48%]
# testing.py::test_mac_computation[layer114-base_model.features.5.0.block.0.2 (SiLU)] PASSED   [ 48%]
# testing.py::test_mac_computation[layer115-base_model.features.5.0.block.1.0 (Conv2d)] PASSED [ 49%]
# testing.py::test_mac_computation[layer116-base_model.features.5.0.block.1.1 (BatchNorm2d)] PASSED [ 49%]
# testing.py::test_mac_computation[layer117-base_model.features.5.0.block.1.2 (SiLU)] PASSED   [ 50%]
# testing.py::test_mac_computation[layer118-base_model.features.5.0.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 50%]
# testing.py::test_mac_computation[layer119-base_model.features.5.0.block.2.fc1 (Conv2d)] PASSED [ 51%]
# testing.py::test_mac_computation[layer120-base_model.features.5.0.block.2.fc2 (Conv2d)] PASSED [ 51%]
# testing.py::test_mac_computation[layer121-base_model.features.5.0.block.2.activation (SiLU)] PASSED [ 51%]
# testing.py::test_mac_computation[layer122-base_model.features.5.0.block.2.scale_activation (Sigmoid)] PASSED [ 52%]
# testing.py::test_mac_computation[layer123-base_model.features.5.0.block.3.0 (Conv2d)] PASSED [ 52%]
# testing.py::test_mac_computation[layer124-base_model.features.5.0.block.3.1 (BatchNorm2d)] PASSED [ 53%]
# testing.py::test_mac_computation[layer125-base_model.features.5.0.stochastic_depth (StochasticDepth)] PASSED [ 53%]
# testing.py::test_mac_computation[layer126-base_model.features.5.1.block.0.0 (Conv2d)] PASSED [ 54%]
# testing.py::test_mac_computation[layer127-base_model.features.5.1.block.0.1 (BatchNorm2d)] PASSED [ 54%]
# testing.py::test_mac_computation[layer128-base_model.features.5.1.block.0.2 (SiLU)] PASSED   [ 54%]
# testing.py::test_mac_computation[layer129-base_model.features.5.1.block.1.0 (Conv2d)] PASSED [ 55%]
# testing.py::test_mac_computation[layer130-base_model.features.5.1.block.1.1 (BatchNorm2d)] PASSED [ 55%]
# testing.py::test_mac_computation[layer131-base_model.features.5.1.block.1.2 (SiLU)] PASSED   [ 56%]
# testing.py::test_mac_computation[layer132-base_model.features.5.1.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 56%]
# testing.py::test_mac_computation[layer133-base_model.features.5.1.block.2.fc1 (Conv2d)] PASSED [ 57%]
# testing.py::test_mac_computation[layer134-base_model.features.5.1.block.2.fc2 (Conv2d)] PASSED [ 57%]
# testing.py::test_mac_computation[layer135-base_model.features.5.1.block.2.activation (SiLU)] PASSED [ 57%]
# testing.py::test_mac_computation[layer136-base_model.features.5.1.block.2.scale_activation (Sigmoid)] PASSED [ 58%]
# testing.py::test_mac_computation[layer137-base_model.features.5.1.block.3.0 (Conv2d)] PASSED [ 58%]
# testing.py::test_mac_computation[layer138-base_model.features.5.1.block.3.1 (BatchNorm2d)] PASSED [ 59%]
# testing.py::test_mac_computation[layer139-base_model.features.5.1.stochastic_depth (StochasticDepth)] PASSED [ 59%]
# testing.py::test_mac_computation[layer140-base_model.features.5.2.block.0.0 (Conv2d)] PASSED [ 60%]
# testing.py::test_mac_computation[layer141-base_model.features.5.2.block.0.1 (BatchNorm2d)] PASSED [ 60%]
# testing.py::test_mac_computation[layer142-base_model.features.5.2.block.0.2 (SiLU)] PASSED   [ 60%]
# testing.py::test_mac_computation[layer143-base_model.features.5.2.block.1.0 (Conv2d)] PASSED [ 61%]
# testing.py::test_mac_computation[layer144-base_model.features.5.2.block.1.1 (BatchNorm2d)] PASSED [ 61%]
# testing.py::test_mac_computation[layer145-base_model.features.5.2.block.1.2 (SiLU)] PASSED   [ 62%]
# testing.py::test_mac_computation[layer146-base_model.features.5.2.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 62%]
# testing.py::test_mac_computation[layer147-base_model.features.5.2.block.2.fc1 (Conv2d)] PASSED [ 62%]
# testing.py::test_mac_computation[layer148-base_model.features.5.2.block.2.fc2 (Conv2d)] PASSED [ 63%]
# testing.py::test_mac_computation[layer149-base_model.features.5.2.block.2.activation (SiLU)] PASSED [ 63%]
# testing.py::test_mac_computation[layer150-base_model.features.5.2.block.2.scale_activation (Sigmoid)] PASSED [ 64%]
# testing.py::test_mac_computation[layer151-base_model.features.5.2.block.3.0 (Conv2d)] PASSED [ 64%]
# testing.py::test_mac_computation[layer152-base_model.features.5.2.block.3.1 (BatchNorm2d)] PASSED [ 65%]
# testing.py::test_mac_computation[layer153-base_model.features.5.2.stochastic_depth (StochasticDepth)] PASSED [ 65%]
# testing.py::test_mac_computation[layer154-base_model.features.6.0.block.0.0 (Conv2d)] PASSED [ 65%]
# testing.py::test_mac_computation[layer155-base_model.features.6.0.block.0.1 (BatchNorm2d)] PASSED [ 66%]
# testing.py::test_mac_computation[layer156-base_model.features.6.0.block.0.2 (SiLU)] PASSED   [ 66%]
# testing.py::test_mac_computation[layer157-base_model.features.6.0.block.1.0 (Conv2d)] PASSED [ 67%]
# testing.py::test_mac_computation[layer158-base_model.features.6.0.block.1.1 (BatchNorm2d)] PASSED [ 67%]
# testing.py::test_mac_computation[layer159-base_model.features.6.0.block.1.2 (SiLU)] PASSED   [ 68%]
# testing.py::test_mac_computation[layer160-base_model.features.6.0.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 68%]
# testing.py::test_mac_computation[layer161-base_model.features.6.0.block.2.fc1 (Conv2d)] PASSED [ 68%]
# testing.py::test_mac_computation[layer162-base_model.features.6.0.block.2.fc2 (Conv2d)] PASSED [ 69%]
# testing.py::test_mac_computation[layer163-base_model.features.6.0.block.2.activation (SiLU)] PASSED [ 69%]
# testing.py::test_mac_computation[layer164-base_model.features.6.0.block.2.scale_activation (Sigmoid)] PASSED [ 70%]
# testing.py::test_mac_computation[layer165-base_model.features.6.0.block.3.0 (Conv2d)] PASSED [ 70%]
# testing.py::test_mac_computation[layer166-base_model.features.6.0.block.3.1 (BatchNorm2d)] PASSED [ 71%]
# testing.py::test_mac_computation[layer167-base_model.features.6.0.stochastic_depth (StochasticDepth)] PASSED [ 71%]
# testing.py::test_mac_computation[layer168-base_model.features.6.1.block.0.0 (Conv2d)] PASSED [ 71%]
# testing.py::test_mac_computation[layer169-base_model.features.6.1.block.0.1 (BatchNorm2d)] PASSED [ 72%]
# testing.py::test_mac_computation[layer170-base_model.features.6.1.block.0.2 (SiLU)] PASSED   [ 72%]
# testing.py::test_mac_computation[layer171-base_model.features.6.1.block.1.0 (Conv2d)] PASSED [ 73%]
# testing.py::test_mac_computation[layer172-base_model.features.6.1.block.1.1 (BatchNorm2d)] PASSED [ 73%]
# testing.py::test_mac_computation[layer173-base_model.features.6.1.block.1.2 (SiLU)] PASSED   [ 74%]
# testing.py::test_mac_computation[layer174-base_model.features.6.1.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 74%]
# testing.py::test_mac_computation[layer175-base_model.features.6.1.block.2.fc1 (Conv2d)] PASSED [ 74%]
# testing.py::test_mac_computation[layer176-base_model.features.6.1.block.2.fc2 (Conv2d)] PASSED [ 75%]
# testing.py::test_mac_computation[layer177-base_model.features.6.1.block.2.activation (SiLU)] PASSED [ 75%]
# testing.py::test_mac_computation[layer178-base_model.features.6.1.block.2.scale_activation (Sigmoid)] PASSED [ 76%]
# testing.py::test_mac_computation[layer179-base_model.features.6.1.block.3.0 (Conv2d)] PASSED [ 76%]
# testing.py::test_mac_computation[layer180-base_model.features.6.1.block.3.1 (BatchNorm2d)] PASSED [ 77%]
# testing.py::test_mac_computation[layer181-base_model.features.6.1.stochastic_depth (StochasticDepth)] PASSED [ 77%]
# testing.py::test_mac_computation[layer182-base_model.features.6.2.block.0.0 (Conv2d)] PASSED [ 77%]
# testing.py::test_mac_computation[layer183-base_model.features.6.2.block.0.1 (BatchNorm2d)] PASSED [ 78%]
# testing.py::test_mac_computation[layer184-base_model.features.6.2.block.0.2 (SiLU)] PASSED   [ 78%]
# testing.py::test_mac_computation[layer185-base_model.features.6.2.block.1.0 (Conv2d)] PASSED [ 79%]
# testing.py::test_mac_computation[layer186-base_model.features.6.2.block.1.1 (BatchNorm2d)] PASSED [ 79%]
# testing.py::test_mac_computation[layer187-base_model.features.6.2.block.1.2 (SiLU)] PASSED   [ 80%]
# testing.py::test_mac_computation[layer188-base_model.features.6.2.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 80%]
# testing.py::test_mac_computation[layer189-base_model.features.6.2.block.2.fc1 (Conv2d)] PASSED [ 80%]
# testing.py::test_mac_computation[layer190-base_model.features.6.2.block.2.fc2 (Conv2d)] PASSED [ 81%]
# testing.py::test_mac_computation[layer191-base_model.features.6.2.block.2.activation (SiLU)] PASSED [ 81%]
# testing.py::test_mac_computation[layer192-base_model.features.6.2.block.2.scale_activation (Sigmoid)] PASSED [ 82%]
# testing.py::test_mac_computation[layer193-base_model.features.6.2.block.3.0 (Conv2d)] PASSED [ 82%]
# testing.py::test_mac_computation[layer194-base_model.features.6.2.block.3.1 (BatchNorm2d)] PASSED [ 82%]
# testing.py::test_mac_computation[layer195-base_model.features.6.2.stochastic_depth (StochasticDepth)] PASSED [ 83%]
# testing.py::test_mac_computation[layer196-base_model.features.6.3.block.0.0 (Conv2d)] PASSED [ 83%]
# testing.py::test_mac_computation[layer197-base_model.features.6.3.block.0.1 (BatchNorm2d)] PASSED [ 84%]
# testing.py::test_mac_computation[layer198-base_model.features.6.3.block.0.2 (SiLU)] PASSED   [ 84%]
# testing.py::test_mac_computation[layer199-base_model.features.6.3.block.1.0 (Conv2d)] PASSED [ 85%]
# testing.py::test_mac_computation[layer200-base_model.features.6.3.block.1.1 (BatchNorm2d)] PASSED [ 85%]
# testing.py::test_mac_computation[layer201-base_model.features.6.3.block.1.2 (SiLU)] PASSED   [ 85%]
# testing.py::test_mac_computation[layer202-base_model.features.6.3.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 86%]
# testing.py::test_mac_computation[layer203-base_model.features.6.3.block.2.fc1 (Conv2d)] PASSED [ 86%]
# testing.py::test_mac_computation[layer204-base_model.features.6.3.block.2.fc2 (Conv2d)] PASSED [ 87%]
# testing.py::test_mac_computation[layer205-base_model.features.6.3.block.2.activation (SiLU)] PASSED [ 87%]
# testing.py::test_mac_computation[layer206-base_model.features.6.3.block.2.scale_activation (Sigmoid)] PASSED [ 88%]
# testing.py::test_mac_computation[layer207-base_model.features.6.3.block.3.0 (Conv2d)] PASSED [ 88%]
# testing.py::test_mac_computation[layer208-base_model.features.6.3.block.3.1 (BatchNorm2d)] PASSED [ 88%]
# testing.py::test_mac_computation[layer209-base_model.features.6.3.stochastic_depth (StochasticDepth)] PASSED [ 89%]
# testing.py::test_mac_computation[layer210-base_model.features.7.0.block.0.0 (Conv2d)] PASSED [ 89%]
# testing.py::test_mac_computation[layer211-base_model.features.7.0.block.0.1 (BatchNorm2d)] PASSED [ 90%]
# testing.py::test_mac_computation[layer212-base_model.features.7.0.block.0.2 (SiLU)] PASSED   [ 90%]
# testing.py::test_mac_computation[layer213-base_model.features.7.0.block.1.0 (Conv2d)] PASSED [ 91%]
# testing.py::test_mac_computation[layer214-base_model.features.7.0.block.1.1 (BatchNorm2d)] PASSED [ 91%]
# testing.py::test_mac_computation[layer215-base_model.features.7.0.block.1.2 (SiLU)] PASSED   [ 91%]
# testing.py::test_mac_computation[layer216-base_model.features.7.0.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 92%]
# testing.py::test_mac_computation[layer217-base_model.features.7.0.block.2.fc1 (Conv2d)] PASSED [ 92%]
# testing.py::test_mac_computation[layer218-base_model.features.7.0.block.2.fc2 (Conv2d)] PASSED [ 93%]
# testing.py::test_mac_computation[layer219-base_model.features.7.0.block.2.activation (SiLU)] PASSED [ 93%]
# testing.py::test_mac_computation[layer220-base_model.features.7.0.block.2.scale_activation (Sigmoid)] PASSED [ 94%]
# testing.py::test_mac_computation[layer221-base_model.features.7.0.block.3.0 (Conv2d)] PASSED [ 94%]
# testing.py::test_mac_computation[layer222-base_model.features.7.0.block.3.1 (BatchNorm2d)] PASSED [ 94%]
# testing.py::test_mac_computation[layer223-base_model.features.7.0.stochastic_depth (StochasticDepth)] PASSED [ 95%]
# testing.py::test_mac_computation[layer224-base_model.features.8.0 (Conv2d)] PASSED           [ 95%]
# testing.py::test_mac_computation[layer225-base_model.features.8.1 (BatchNorm2d)] PASSED      [ 96%]
# testing.py::test_mac_computation[layer226-base_model.features.8.2 (SiLU)] PASSED             [ 96%]
# testing.py::test_mac_computation[layer227-base_model.avgpool (AdaptiveAvgPool2d)] PASSED     [ 97%]
# testing.py::test_mac_computation[layer228-base_model.classifier.0 (Dropout)] PASSED          [ 97%]
# testing.py::test_mac_computation[layer229-base_model.classifier.1 (Linear)] PASSED           [ 97%]
# testing.py::test_mac_computation[layer230-pooling (AdaptiveAvgPool2d)] PASSED                [ 98%]
# testing.py::test_mac_computation[layer231-fc1 (Linear)] PASSED                               [ 98%]
# testing.py::test_mac_computation[layer232-relu (ReLU)] PASSED                                [ 99%]
# testing.py::test_mac_computation[layer233-fc2 (Linear)] PASSED                               [ 99%]
# testing.py::test_mac_computation[layer234-softmax (Softmax)] PASSED                          [100%]
#
# ================================== 235 passed in 61.10s (0:01:01) ==================================

# %% [markdown]
# **Unit Tests for EfficientNet (with batchnorm)**

# %%
# !pytest -v testing.py --model=efficientnet2
# Out:
# ======================================= test session starts ========================================
# platform linux -- Python 3.11.11, pytest-8.3.4, pluggy-1.5.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content
# plugins: typeguard-4.4.1, anyio-3.7.1
# collected 236 items
#
# testing.py::test_mac_computation[layer0-base_model.features.0.0 (Conv2d)] PASSED             [  0%]
# testing.py::test_mac_computation[layer1-base_model.features.0.1 (BatchNorm2d)] PASSED        [  0%]
# testing.py::test_mac_computation[layer2-base_model.features.0.2 (SiLU)] PASSED               [  1%]
# testing.py::test_mac_computation[layer3-base_model.features.1.0.block.0.0 (Conv2d)] PASSED   [  1%]
# testing.py::test_mac_computation[layer4-base_model.features.1.0.block.0.1 (BatchNorm2d)] PASSED [  2%]
# testing.py::test_mac_computation[layer5-base_model.features.1.0.block.0.2 (SiLU)] PASSED     [  2%]
# testing.py::test_mac_computation[layer6-base_model.features.1.0.block.1.avgpool (AdaptiveAvgPool2d)] PASSED [  2%]
# testing.py::test_mac_computation[layer7-base_model.features.1.0.block.1.fc1 (Conv2d)] PASSED [  3%]
# testing.py::test_mac_computation[layer8-base_model.features.1.0.block.1.fc2 (Conv2d)] PASSED [  3%]
# testing.py::test_mac_computation[layer9-base_model.features.1.0.block.1.activation (SiLU)] PASSED [  4%]
# testing.py::test_mac_computation[layer10-base_model.features.1.0.block.1.scale_activation (Sigmoid)] PASSED [  4%]
# testing.py::test_mac_computation[layer11-base_model.features.1.0.block.2.0 (Conv2d)] PASSED  [  5%]
# testing.py::test_mac_computation[layer12-base_model.features.1.0.block.2.1 (BatchNorm2d)] PASSED [  5%]
# testing.py::test_mac_computation[layer13-base_model.features.1.0.stochastic_depth (StochasticDepth)] PASSED [  5%]
# testing.py::test_mac_computation[layer14-base_model.features.2.0.block.0.0 (Conv2d)] PASSED  [  6%]
# testing.py::test_mac_computation[layer15-base_model.features.2.0.block.0.1 (BatchNorm2d)] PASSED [  6%]
# testing.py::test_mac_computation[layer16-base_model.features.2.0.block.0.2 (SiLU)] PASSED    [  7%]
# testing.py::test_mac_computation[layer17-base_model.features.2.0.block.1.0 (Conv2d)] PASSED  [  7%]
# testing.py::test_mac_computation[layer18-base_model.features.2.0.block.1.1 (BatchNorm2d)] PASSED [  8%]
# testing.py::test_mac_computation[layer19-base_model.features.2.0.block.1.2 (SiLU)] PASSED    [  8%]
# testing.py::test_mac_computation[layer20-base_model.features.2.0.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [  8%]
# testing.py::test_mac_computation[layer21-base_model.features.2.0.block.2.fc1 (Conv2d)] PASSED [  9%]
# testing.py::test_mac_computation[layer22-base_model.features.2.0.block.2.fc2 (Conv2d)] PASSED [  9%]
# testing.py::test_mac_computation[layer23-base_model.features.2.0.block.2.activation (SiLU)] PASSED [ 10%]
# testing.py::test_mac_computation[layer24-base_model.features.2.0.block.2.scale_activation (Sigmoid)] PASSED [ 10%]
# testing.py::test_mac_computation[layer25-base_model.features.2.0.block.3.0 (Conv2d)] PASSED  [ 11%]
# testing.py::test_mac_computation[layer26-base_model.features.2.0.block.3.1 (BatchNorm2d)] PASSED [ 11%]
# testing.py::test_mac_computation[layer27-base_model.features.2.0.stochastic_depth (StochasticDepth)] PASSED [ 11%]
# testing.py::test_mac_computation[layer28-base_model.features.2.1.block.0.0 (Conv2d)] PASSED  [ 12%]
# testing.py::test_mac_computation[layer29-base_model.features.2.1.block.0.1 (BatchNorm2d)] PASSED [ 12%]
# testing.py::test_mac_computation[layer30-base_model.features.2.1.block.0.2 (SiLU)] PASSED    [ 13%]
# testing.py::test_mac_computation[layer31-base_model.features.2.1.block.1.0 (Conv2d)] PASSED  [ 13%]
# testing.py::test_mac_computation[layer32-base_model.features.2.1.block.1.1 (BatchNorm2d)] PASSED [ 13%]
# testing.py::test_mac_computation[layer33-base_model.features.2.1.block.1.2 (SiLU)] PASSED    [ 14%]
# testing.py::test_mac_computation[layer34-base_model.features.2.1.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 14%]
# testing.py::test_mac_computation[layer35-base_model.features.2.1.block.2.fc1 (Conv2d)] PASSED [ 15%]
# testing.py::test_mac_computation[layer36-base_model.features.2.1.block.2.fc2 (Conv2d)] PASSED [ 15%]
# testing.py::test_mac_computation[layer37-base_model.features.2.1.block.2.activation (SiLU)] PASSED [ 16%]
# testing.py::test_mac_computation[layer38-base_model.features.2.1.block.2.scale_activation (Sigmoid)] PASSED [ 16%]
# testing.py::test_mac_computation[layer39-base_model.features.2.1.block.3.0 (Conv2d)] PASSED  [ 16%]
# testing.py::test_mac_computation[layer40-base_model.features.2.1.block.3.1 (BatchNorm2d)] PASSED [ 17%]
# testing.py::test_mac_computation[layer41-base_model.features.2.1.stochastic_depth (StochasticDepth)] PASSED [ 17%]
# testing.py::test_mac_computation[layer42-base_model.features.3.0.block.0.0 (Conv2d)] PASSED  [ 18%]
# testing.py::test_mac_computation[layer43-base_model.features.3.0.block.0.1 (BatchNorm2d)] PASSED [ 18%]
# testing.py::test_mac_computation[layer44-base_model.features.3.0.block.0.2 (SiLU)] PASSED    [ 19%]
# testing.py::test_mac_computation[layer45-base_model.features.3.0.block.1.0 (Conv2d)] PASSED  [ 19%]
# testing.py::test_mac_computation[layer46-base_model.features.3.0.block.1.1 (BatchNorm2d)] PASSED [ 19%]
# testing.py::test_mac_computation[layer47-base_model.features.3.0.block.1.2 (SiLU)] PASSED    [ 20%]
# testing.py::test_mac_computation[layer48-base_model.features.3.0.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 20%]
# testing.py::test_mac_computation[layer49-base_model.features.3.0.block.2.fc1 (Conv2d)] PASSED [ 21%]
# testing.py::test_mac_computation[layer50-base_model.features.3.0.block.2.fc2 (Conv2d)] PASSED [ 21%]
# testing.py::test_mac_computation[layer51-base_model.features.3.0.block.2.activation (SiLU)] PASSED [ 22%]
# testing.py::test_mac_computation[layer52-base_model.features.3.0.block.2.scale_activation (Sigmoid)] PASSED [ 22%]
# testing.py::test_mac_computation[layer53-base_model.features.3.0.block.3.0 (Conv2d)] PASSED  [ 22%]
# testing.py::test_mac_computation[layer54-base_model.features.3.0.block.3.1 (BatchNorm2d)] PASSED [ 23%]
# testing.py::test_mac_computation[layer55-base_model.features.3.0.stochastic_depth (StochasticDepth)] PASSED [ 23%]
# testing.py::test_mac_computation[layer56-base_model.features.3.1.block.0.0 (Conv2d)] PASSED  [ 24%]
# testing.py::test_mac_computation[layer57-base_model.features.3.1.block.0.1 (BatchNorm2d)] PASSED [ 24%]
# testing.py::test_mac_computation[layer58-base_model.features.3.1.block.0.2 (SiLU)] PASSED    [ 25%]
# testing.py::test_mac_computation[layer59-base_model.features.3.1.block.1.0 (Conv2d)] PASSED  [ 25%]
# testing.py::test_mac_computation[layer60-base_model.features.3.1.block.1.1 (BatchNorm2d)] PASSED [ 25%]
# testing.py::test_mac_computation[layer61-base_model.features.3.1.block.1.2 (SiLU)] PASSED    [ 26%]
# testing.py::test_mac_computation[layer62-base_model.features.3.1.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 26%]
# testing.py::test_mac_computation[layer63-base_model.features.3.1.block.2.fc1 (Conv2d)] PASSED [ 27%]
# testing.py::test_mac_computation[layer64-base_model.features.3.1.block.2.fc2 (Conv2d)] PASSED [ 27%]
# testing.py::test_mac_computation[layer65-base_model.features.3.1.block.2.activation (SiLU)] PASSED [ 27%]
# testing.py::test_mac_computation[layer66-base_model.features.3.1.block.2.scale_activation (Sigmoid)] PASSED [ 28%]
# testing.py::test_mac_computation[layer67-base_model.features.3.1.block.3.0 (Conv2d)] PASSED  [ 28%]
# testing.py::test_mac_computation[layer68-base_model.features.3.1.block.3.1 (BatchNorm2d)] PASSED [ 29%]
# testing.py::test_mac_computation[layer69-base_model.features.3.1.stochastic_depth (StochasticDepth)] PASSED [ 29%]
# testing.py::test_mac_computation[layer70-base_model.features.4.0.block.0.0 (Conv2d)] PASSED  [ 30%]
# testing.py::test_mac_computation[layer71-base_model.features.4.0.block.0.1 (BatchNorm2d)] PASSED [ 30%]
# testing.py::test_mac_computation[layer72-base_model.features.4.0.block.0.2 (SiLU)] PASSED    [ 30%]
# testing.py::test_mac_computation[layer73-base_model.features.4.0.block.1.0 (Conv2d)] PASSED  [ 31%]
# testing.py::test_mac_computation[layer74-base_model.features.4.0.block.1.1 (BatchNorm2d)] PASSED [ 31%]
# testing.py::test_mac_computation[layer75-base_model.features.4.0.block.1.2 (SiLU)] PASSED    [ 32%]
# testing.py::test_mac_computation[layer76-base_model.features.4.0.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 32%]
# testing.py::test_mac_computation[layer77-base_model.features.4.0.block.2.fc1 (Conv2d)] PASSED [ 33%]
# testing.py::test_mac_computation[layer78-base_model.features.4.0.block.2.fc2 (Conv2d)] PASSED [ 33%]
# testing.py::test_mac_computation[layer79-base_model.features.4.0.block.2.activation (SiLU)] PASSED [ 33%]
# testing.py::test_mac_computation[layer80-base_model.features.4.0.block.2.scale_activation (Sigmoid)] PASSED [ 34%]
# testing.py::test_mac_computation[layer81-base_model.features.4.0.block.3.0 (Conv2d)] PASSED  [ 34%]
# testing.py::test_mac_computation[layer82-base_model.features.4.0.block.3.1 (BatchNorm2d)] PASSED [ 35%]
# testing.py::test_mac_computation[layer83-base_model.features.4.0.stochastic_depth (StochasticDepth)] PASSED [ 35%]
# testing.py::test_mac_computation[layer84-base_model.features.4.1.block.0.0 (Conv2d)] PASSED  [ 36%]
# testing.py::test_mac_computation[layer85-base_model.features.4.1.block.0.1 (BatchNorm2d)] PASSED [ 36%]
# testing.py::test_mac_computation[layer86-base_model.features.4.1.block.0.2 (SiLU)] PASSED    [ 36%]
# testing.py::test_mac_computation[layer87-base_model.features.4.1.block.1.0 (Conv2d)] PASSED  [ 37%]
# testing.py::test_mac_computation[layer88-base_model.features.4.1.block.1.1 (BatchNorm2d)] PASSED [ 37%]
# testing.py::test_mac_computation[layer89-base_model.features.4.1.block.1.2 (SiLU)] PASSED    [ 38%]
# testing.py::test_mac_computation[layer90-base_model.features.4.1.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 38%]
# testing.py::test_mac_computation[layer91-base_model.features.4.1.block.2.fc1 (Conv2d)] PASSED [ 38%]
# testing.py::test_mac_computation[layer92-base_model.features.4.1.block.2.fc2 (Conv2d)] PASSED [ 39%]
# testing.py::test_mac_computation[layer93-base_model.features.4.1.block.2.activation (SiLU)] PASSED [ 39%]
# testing.py::test_mac_computation[layer94-base_model.features.4.1.block.2.scale_activation (Sigmoid)] PASSED [ 40%]
# testing.py::test_mac_computation[layer95-base_model.features.4.1.block.3.0 (Conv2d)] PASSED  [ 40%]
# testing.py::test_mac_computation[layer96-base_model.features.4.1.block.3.1 (BatchNorm2d)] PASSED [ 41%]
# testing.py::test_mac_computation[layer97-base_model.features.4.1.stochastic_depth (StochasticDepth)] PASSED [ 41%]
# testing.py::test_mac_computation[layer98-base_model.features.4.2.block.0.0 (Conv2d)] PASSED  [ 41%]
# testing.py::test_mac_computation[layer99-base_model.features.4.2.block.0.1 (BatchNorm2d)] PASSED [ 42%]
# testing.py::test_mac_computation[layer100-base_model.features.4.2.block.0.2 (SiLU)] PASSED   [ 42%]
# testing.py::test_mac_computation[layer101-base_model.features.4.2.block.1.0 (Conv2d)] PASSED [ 43%]
# testing.py::test_mac_computation[layer102-base_model.features.4.2.block.1.1 (BatchNorm2d)] PASSED [ 43%]
# testing.py::test_mac_computation[layer103-base_model.features.4.2.block.1.2 (SiLU)] PASSED   [ 44%]
# testing.py::test_mac_computation[layer104-base_model.features.4.2.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 44%]
# testing.py::test_mac_computation[layer105-base_model.features.4.2.block.2.fc1 (Conv2d)] PASSED [ 44%]
# testing.py::test_mac_computation[layer106-base_model.features.4.2.block.2.fc2 (Conv2d)] PASSED [ 45%]
# testing.py::test_mac_computation[layer107-base_model.features.4.2.block.2.activation (SiLU)] PASSED [ 45%]
# testing.py::test_mac_computation[layer108-base_model.features.4.2.block.2.scale_activation (Sigmoid)] PASSED [ 46%]
# testing.py::test_mac_computation[layer109-base_model.features.4.2.block.3.0 (Conv2d)] PASSED [ 46%]
# testing.py::test_mac_computation[layer110-base_model.features.4.2.block.3.1 (BatchNorm2d)] PASSED [ 47%]
# testing.py::test_mac_computation[layer111-base_model.features.4.2.stochastic_depth (StochasticDepth)] PASSED [ 47%]
# testing.py::test_mac_computation[layer112-base_model.features.5.0.block.0.0 (Conv2d)] PASSED [ 47%]
# testing.py::test_mac_computation[layer113-base_model.features.5.0.block.0.1 (BatchNorm2d)] PASSED [ 48%]
# testing.py::test_mac_computation[layer114-base_model.features.5.0.block.0.2 (SiLU)] PASSED   [ 48%]
# testing.py::test_mac_computation[layer115-base_model.features.5.0.block.1.0 (Conv2d)] PASSED [ 49%]
# testing.py::test_mac_computation[layer116-base_model.features.5.0.block.1.1 (BatchNorm2d)] PASSED [ 49%]
# testing.py::test_mac_computation[layer117-base_model.features.5.0.block.1.2 (SiLU)] PASSED   [ 50%]
# testing.py::test_mac_computation[layer118-base_model.features.5.0.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 50%]
# testing.py::test_mac_computation[layer119-base_model.features.5.0.block.2.fc1 (Conv2d)] PASSED [ 50%]
# testing.py::test_mac_computation[layer120-base_model.features.5.0.block.2.fc2 (Conv2d)] PASSED [ 51%]
# testing.py::test_mac_computation[layer121-base_model.features.5.0.block.2.activation (SiLU)] PASSED [ 51%]
# testing.py::test_mac_computation[layer122-base_model.features.5.0.block.2.scale_activation (Sigmoid)] PASSED [ 52%]
# testing.py::test_mac_computation[layer123-base_model.features.5.0.block.3.0 (Conv2d)] PASSED [ 52%]
# testing.py::test_mac_computation[layer124-base_model.features.5.0.block.3.1 (BatchNorm2d)] PASSED [ 52%]
# testing.py::test_mac_computation[layer125-base_model.features.5.0.stochastic_depth (StochasticDepth)] PASSED [ 53%]
# testing.py::test_mac_computation[layer126-base_model.features.5.1.block.0.0 (Conv2d)] PASSED [ 53%]
# testing.py::test_mac_computation[layer127-base_model.features.5.1.block.0.1 (BatchNorm2d)] PASSED [ 54%]
# testing.py::test_mac_computation[layer128-base_model.features.5.1.block.0.2 (SiLU)] PASSED   [ 54%]
# testing.py::test_mac_computation[layer129-base_model.features.5.1.block.1.0 (Conv2d)] PASSED [ 55%]
# testing.py::test_mac_computation[layer130-base_model.features.5.1.block.1.1 (BatchNorm2d)] PASSED [ 55%]
# testing.py::test_mac_computation[layer131-base_model.features.5.1.block.1.2 (SiLU)] PASSED   [ 55%]
# testing.py::test_mac_computation[layer132-base_model.features.5.1.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 56%]
# testing.py::test_mac_computation[layer133-base_model.features.5.1.block.2.fc1 (Conv2d)] PASSED [ 56%]
# testing.py::test_mac_computation[layer134-base_model.features.5.1.block.2.fc2 (Conv2d)] PASSED [ 57%]
# testing.py::test_mac_computation[layer135-base_model.features.5.1.block.2.activation (SiLU)] PASSED [ 57%]
# testing.py::test_mac_computation[layer136-base_model.features.5.1.block.2.scale_activation (Sigmoid)] PASSED [ 58%]
# testing.py::test_mac_computation[layer137-base_model.features.5.1.block.3.0 (Conv2d)] PASSED [ 58%]
# testing.py::test_mac_computation[layer138-base_model.features.5.1.block.3.1 (BatchNorm2d)] PASSED [ 58%]
# testing.py::test_mac_computation[layer139-base_model.features.5.1.stochastic_depth (StochasticDepth)] PASSED [ 59%]
# testing.py::test_mac_computation[layer140-base_model.features.5.2.block.0.0 (Conv2d)] PASSED [ 59%]
# testing.py::test_mac_computation[layer141-base_model.features.5.2.block.0.1 (BatchNorm2d)] PASSED [ 60%]
# testing.py::test_mac_computation[layer142-base_model.features.5.2.block.0.2 (SiLU)] PASSED   [ 60%]
# testing.py::test_mac_computation[layer143-base_model.features.5.2.block.1.0 (Conv2d)] PASSED [ 61%]
# testing.py::test_mac_computation[layer144-base_model.features.5.2.block.1.1 (BatchNorm2d)] PASSED [ 61%]
# testing.py::test_mac_computation[layer145-base_model.features.5.2.block.1.2 (SiLU)] PASSED   [ 61%]
# testing.py::test_mac_computation[layer146-base_model.features.5.2.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 62%]
# testing.py::test_mac_computation[layer147-base_model.features.5.2.block.2.fc1 (Conv2d)] PASSED [ 62%]
# testing.py::test_mac_computation[layer148-base_model.features.5.2.block.2.fc2 (Conv2d)] PASSED [ 63%]
# testing.py::test_mac_computation[layer149-base_model.features.5.2.block.2.activation (SiLU)] PASSED [ 63%]
# testing.py::test_mac_computation[layer150-base_model.features.5.2.block.2.scale_activation (Sigmoid)] PASSED [ 63%]
# testing.py::test_mac_computation[layer151-base_model.features.5.2.block.3.0 (Conv2d)] PASSED [ 64%]
# testing.py::test_mac_computation[layer152-base_model.features.5.2.block.3.1 (BatchNorm2d)] PASSED [ 64%]
# testing.py::test_mac_computation[layer153-base_model.features.5.2.stochastic_depth (StochasticDepth)] PASSED [ 65%]
# testing.py::test_mac_computation[layer154-base_model.features.6.0.block.0.0 (Conv2d)] PASSED [ 65%]
# testing.py::test_mac_computation[layer155-base_model.features.6.0.block.0.1 (BatchNorm2d)] PASSED [ 66%]
# testing.py::test_mac_computation[layer156-base_model.features.6.0.block.0.2 (SiLU)] PASSED   [ 66%]
# testing.py::test_mac_computation[layer157-base_model.features.6.0.block.1.0 (Conv2d)] PASSED [ 66%]
# testing.py::test_mac_computation[layer158-base_model.features.6.0.block.1.1 (BatchNorm2d)] PASSED [ 67%]
# testing.py::test_mac_computation[layer159-base_model.features.6.0.block.1.2 (SiLU)] PASSED   [ 67%]
# testing.py::test_mac_computation[layer160-base_model.features.6.0.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 68%]
# testing.py::test_mac_computation[layer161-base_model.features.6.0.block.2.fc1 (Conv2d)] PASSED [ 68%]
# testing.py::test_mac_computation[layer162-base_model.features.6.0.block.2.fc2 (Conv2d)] PASSED [ 69%]
# testing.py::test_mac_computation[layer163-base_model.features.6.0.block.2.activation (SiLU)] PASSED [ 69%]
# testing.py::test_mac_computation[layer164-base_model.features.6.0.block.2.scale_activation (Sigmoid)] PASSED [ 69%]
# testing.py::test_mac_computation[layer165-base_model.features.6.0.block.3.0 (Conv2d)] PASSED [ 70%]
# testing.py::test_mac_computation[layer166-base_model.features.6.0.block.3.1 (BatchNorm2d)] PASSED [ 70%]
# testing.py::test_mac_computation[layer167-base_model.features.6.0.stochastic_depth (StochasticDepth)] PASSED [ 71%]
# testing.py::test_mac_computation[layer168-base_model.features.6.1.block.0.0 (Conv2d)] PASSED [ 71%]
# testing.py::test_mac_computation[layer169-base_model.features.6.1.block.0.1 (BatchNorm2d)] PASSED [ 72%]
# testing.py::test_mac_computation[layer170-base_model.features.6.1.block.0.2 (SiLU)] PASSED   [ 72%]
# testing.py::test_mac_computation[layer171-base_model.features.6.1.block.1.0 (Conv2d)] PASSED [ 72%]
# testing.py::test_mac_computation[layer172-base_model.features.6.1.block.1.1 (BatchNorm2d)] PASSED [ 73%]
# testing.py::test_mac_computation[layer173-base_model.features.6.1.block.1.2 (SiLU)] PASSED   [ 73%]
# testing.py::test_mac_computation[layer174-base_model.features.6.1.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 74%]
# testing.py::test_mac_computation[layer175-base_model.features.6.1.block.2.fc1 (Conv2d)] PASSED [ 74%]
# testing.py::test_mac_computation[layer176-base_model.features.6.1.block.2.fc2 (Conv2d)] PASSED [ 75%]
# testing.py::test_mac_computation[layer177-base_model.features.6.1.block.2.activation (SiLU)] PASSED [ 75%]
# testing.py::test_mac_computation[layer178-base_model.features.6.1.block.2.scale_activation (Sigmoid)] PASSED [ 75%]
# testing.py::test_mac_computation[layer179-base_model.features.6.1.block.3.0 (Conv2d)] PASSED [ 76%]
# testing.py::test_mac_computation[layer180-base_model.features.6.1.block.3.1 (BatchNorm2d)] PASSED [ 76%]
# testing.py::test_mac_computation[layer181-base_model.features.6.1.stochastic_depth (StochasticDepth)] PASSED [ 77%]
# testing.py::test_mac_computation[layer182-base_model.features.6.2.block.0.0 (Conv2d)] PASSED [ 77%]
# testing.py::test_mac_computation[layer183-base_model.features.6.2.block.0.1 (BatchNorm2d)] PASSED [ 77%]
# testing.py::test_mac_computation[layer184-base_model.features.6.2.block.0.2 (SiLU)] PASSED   [ 78%]
# testing.py::test_mac_computation[layer185-base_model.features.6.2.block.1.0 (Conv2d)] PASSED [ 78%]
# testing.py::test_mac_computation[layer186-base_model.features.6.2.block.1.1 (BatchNorm2d)] PASSED [ 79%]
# testing.py::test_mac_computation[layer187-base_model.features.6.2.block.1.2 (SiLU)] PASSED   [ 79%]
# testing.py::test_mac_computation[layer188-base_model.features.6.2.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 80%]
# testing.py::test_mac_computation[layer189-base_model.features.6.2.block.2.fc1 (Conv2d)] PASSED [ 80%]
# testing.py::test_mac_computation[layer190-base_model.features.6.2.block.2.fc2 (Conv2d)] PASSED [ 80%]
# testing.py::test_mac_computation[layer191-base_model.features.6.2.block.2.activation (SiLU)] PASSED [ 81%]
# testing.py::test_mac_computation[layer192-base_model.features.6.2.block.2.scale_activation (Sigmoid)] PASSED [ 81%]
# testing.py::test_mac_computation[layer193-base_model.features.6.2.block.3.0 (Conv2d)] PASSED [ 82%]
# testing.py::test_mac_computation[layer194-base_model.features.6.2.block.3.1 (BatchNorm2d)] PASSED [ 82%]
# testing.py::test_mac_computation[layer195-base_model.features.6.2.stochastic_depth (StochasticDepth)] PASSED [ 83%]
# testing.py::test_mac_computation[layer196-base_model.features.6.3.block.0.0 (Conv2d)] PASSED [ 83%]
# testing.py::test_mac_computation[layer197-base_model.features.6.3.block.0.1 (BatchNorm2d)] PASSED [ 83%]
# testing.py::test_mac_computation[layer198-base_model.features.6.3.block.0.2 (SiLU)] PASSED   [ 84%]
# testing.py::test_mac_computation[layer199-base_model.features.6.3.block.1.0 (Conv2d)] PASSED [ 84%]
# testing.py::test_mac_computation[layer200-base_model.features.6.3.block.1.1 (BatchNorm2d)] PASSED [ 85%]
# testing.py::test_mac_computation[layer201-base_model.features.6.3.block.1.2 (SiLU)] PASSED   [ 85%]
# testing.py::test_mac_computation[layer202-base_model.features.6.3.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 86%]
# testing.py::test_mac_computation[layer203-base_model.features.6.3.block.2.fc1 (Conv2d)] PASSED [ 86%]
# testing.py::test_mac_computation[layer204-base_model.features.6.3.block.2.fc2 (Conv2d)] PASSED [ 86%]
# testing.py::test_mac_computation[layer205-base_model.features.6.3.block.2.activation (SiLU)] PASSED [ 87%]
# testing.py::test_mac_computation[layer206-base_model.features.6.3.block.2.scale_activation (Sigmoid)] PASSED [ 87%]
# testing.py::test_mac_computation[layer207-base_model.features.6.3.block.3.0 (Conv2d)] PASSED [ 88%]
# testing.py::test_mac_computation[layer208-base_model.features.6.3.block.3.1 (BatchNorm2d)] PASSED [ 88%]
# testing.py::test_mac_computation[layer209-base_model.features.6.3.stochastic_depth (StochasticDepth)] PASSED [ 88%]
# testing.py::test_mac_computation[layer210-base_model.features.7.0.block.0.0 (Conv2d)] PASSED [ 89%]
# testing.py::test_mac_computation[layer211-base_model.features.7.0.block.0.1 (BatchNorm2d)] PASSED [ 89%]
# testing.py::test_mac_computation[layer212-base_model.features.7.0.block.0.2 (SiLU)] PASSED   [ 90%]
# testing.py::test_mac_computation[layer213-base_model.features.7.0.block.1.0 (Conv2d)] PASSED [ 90%]
# testing.py::test_mac_computation[layer214-base_model.features.7.0.block.1.1 (BatchNorm2d)] PASSED [ 91%]
# testing.py::test_mac_computation[layer215-base_model.features.7.0.block.1.2 (SiLU)] PASSED   [ 91%]
# testing.py::test_mac_computation[layer216-base_model.features.7.0.block.2.avgpool (AdaptiveAvgPool2d)] PASSED [ 91%]
# testing.py::test_mac_computation[layer217-base_model.features.7.0.block.2.fc1 (Conv2d)] PASSED [ 92%]
# testing.py::test_mac_computation[layer218-base_model.features.7.0.block.2.fc2 (Conv2d)] PASSED [ 92%]
# testing.py::test_mac_computation[layer219-base_model.features.7.0.block.2.activation (SiLU)] PASSED [ 93%]
# testing.py::test_mac_computation[layer220-base_model.features.7.0.block.2.scale_activation (Sigmoid)] PASSED [ 93%]
# testing.py::test_mac_computation[layer221-base_model.features.7.0.block.3.0 (Conv2d)] PASSED [ 94%]
# testing.py::test_mac_computation[layer222-base_model.features.7.0.block.3.1 (BatchNorm2d)] PASSED [ 94%]
# testing.py::test_mac_computation[layer223-base_model.features.7.0.stochastic_depth (StochasticDepth)] PASSED [ 94%]
# testing.py::test_mac_computation[layer224-base_model.features.8.0 (Conv2d)] PASSED           [ 95%]
# testing.py::test_mac_computation[layer225-base_model.features.8.1 (BatchNorm2d)] PASSED      [ 95%]
# testing.py::test_mac_computation[layer226-base_model.features.8.2 (SiLU)] PASSED             [ 96%]
# testing.py::test_mac_computation[layer227-base_model.avgpool (AdaptiveAvgPool2d)] PASSED     [ 96%]
# testing.py::test_mac_computation[layer228-base_model.classifier.0 (Dropout)] PASSED          [ 97%]
# testing.py::test_mac_computation[layer229-base_model.classifier.1 (Linear)] PASSED           [ 97%]
# testing.py::test_mac_computation[layer230-pooling (AdaptiveAvgPool2d)] PASSED                [ 97%]
# testing.py::test_mac_computation[layer231-batch_norm (BatchNorm1d)] PASSED                   [ 98%]
# testing.py::test_mac_computation[layer232-fc1 (Linear)] PASSED                               [ 98%]
# testing.py::test_mac_computation[layer233-relu (ReLU)] PASSED                                [ 99%]
# testing.py::test_mac_computation[layer234-fc2 (Linear)] PASSED                               [ 99%]
# testing.py::test_mac_computation[layer235-softmax (Softmax)] PASSED                          [100%]
#
# ======================================= 236 passed in 58.57s =======================================
